# %%
import pydicom
import os
import matplotlib.pyplot as plt

# %%
# Path to a DICOM file
dicom_path = f'D:/LIDC_dataset/LIDC-IDRI/LIDC-IDRI-0001/01-01-2000-NA-NA-30178/3000566.000000-NA-03192/1-025.dcm'
#dicom_path = 'D:/LIDC_dataset/manifest-1600709154662/LIDC-IDRI/LIDC-IDRI-0001/01-01-2000-NA-NA-35511/3000923.000000-NA-62357/1-1.dcm'

# Read the DICOM file
dicom = pydicom.dcmread(dicom_path)

# Access image data
image = dicom.pixel_array

# Display the image
plt.imshow(image, cmap='gray')
plt.title(f"Slice Number: {dicom.InstanceNumber}")
plt.show()
